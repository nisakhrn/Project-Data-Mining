# %% [markdown]
# # Tema 2: Clustering Kabupaten/Kota Aceh Berdasarkan Skala Infrastruktur Pendidikan
#
# **Skenario 1 — Clustering** | Dataset: `data_bersih.csv`
#
# **Pertanyaan:** Kabupaten mana yang infrastruktur pendidikannya (sekolah, guru, murid) paling besar/kecil?

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

sns.set_style("whitegrid")

pd.set_option("display.max_columns",None)

print("Library berhasil diimport.")
# Out:
# Library berhasil diimport.

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv('data_bersih.csv')
print("Ukuran data:", df.shape)
print("Jumlah kabupaten/kota:", df['kabupaten_kota'].nunique())
print("Rentang tahun:", df['tahun'].min(), "-", df['tahun'].max())
print("Missing value:", df.isnull().sum().sum())
print("Duplikat:", df.duplicated().sum())
df.head()
# Out:
# Ukuran data: (230, 41)
# Jumlah kabupaten/kota: 23
# Rentang tahun: 2016 - 2025
# Missing value: 0
# Duplikat: 0
#          kabupaten_kota  tahun  hls__nilai  rls__nilai  amh__nilai  \
# 0  Kabupaten Aceh Barat   2016       14.56        8.70       97.84
# 1  Kabupaten Aceh Barat   2017       14.57        9.04       97.84
# 2  Kabupaten Aceh Barat   2018       14.58        9.08       97.84
# 3  Kabupaten Aceh Barat   2019       14.59        9.09       97.84
# 4  Kabupaten Aceh Barat   2020       14.60        9.37       97.84
#
#    sd__Jumlah Sekolah SD (Negeri)  sd__Jumlah Sekolah SD (Swasta)  \
# 0                             148                               4
# 1                             150                               3
# 2                             150                               3
# 3                             150                               3
# 4                             150                               3
#
#    sd__Jumlah Sekolah SD (Negeri+Swasta)  sd__Jumlah Guru SD (Negeri)  \
# 0                                    153                         2125
# 1                                    153                         2050
# 2                                    153                         2127
# 3                                    153                         2276
# 4                                    153                         2367
#
#    sd__Jumlah Guru SD (Swasta)  sd__Jumlah Guru SD (Negeri+Swasta)  \
# 0                           48                                2315
# 1                           41                                2091
# 2                           36                                2163
# 3                           39                                2315
# 4                           38                                2405
#
#    sd__Jumlah Murid SD (Negeri)  sd__Jumlah Murid SD (Swasta)  \
# 0                         15757                           422
# 1                         16169                           414
# 2                         15694                           467
# 3                         15718                           515
# 4                         15377                           542
#
#    sd__Jumlah Murid SD (Negeri+Swasta)  smp__Jumlah Sekolah SMP (Negeri)  \
# 0                                16233                                39
# 1                                16583                                45
# 2                                16161                                45
# 3                                16233                                45
# 4                                15919                                45
#
#    smp__Jumlah Sekolah SMP (Swasta)  smp__Jumlah Sekolah SMP (Negeri+Swasta)  \
# 0                                10                                       49
# 1                                 8                                       53
# 2                                 9                                       54
# 3                                11                                       56
# 4                                13                                       58
#
#    smp__Jumlah Guru SMP (Negeri)  smp__Jumlah Guru SMP (Swasta)  \
# 0                            658                             93
# 1                            727                             88
# 2                            757                            106
# 3                            774                            130
# 4                            850                            173
#
#    smp__Jumlah Guru SMP (Negeri+Swasta)  smp__Jumlah Murid SMP (Negeri)  \
# 0                                   751                            5270
# 1                                   815                            5427
# 2                                   863                            5391
# 3                                   904                            5649
# 4                                  1023                            5544
#
#    smp__Jumlah Murid SMP (Swasta)  smp__Jumlah Murid SMP (Negeri+Swasta)  \
# 0                             698                                   5968
# 1                             631                                   6058
# 2                             783                                   6174
# 3                            1006                                   6655
# 4                            1176                                   6720
#
#    sma__Jumlah Sekolah SMA (Negeri)  sma__Jumlah Sekolah SMA (Swasta)  \
# 0                                17                                 4
# 1                                17                                 4
# 2                                17                                 4
# 3                                17                                 4
# 4                                17                                 4
#
#    sma__Jumlah Sekolah SMA (Negeri+Swasta)  sma__Jumlah Guru SMA (Negeri)  \
# 0                                       21                            434
# 1                                       21                            431
# 2                                       21                            421
# 3                                       21                            423
# 4                                       21                            433
#
#    sma__Jumlah Guru SMA (Swasta)  sma__Jumlah Guru SMA (Negeri+Swasta)  \
# 0                             58                                   492
# 1                             61                                   492
# 2                             65                                   486
# 3                             67                                   490
# 4                             68                                   501
#
#    sma__Jumlah Murid SMA (Negeri)  sma__Jumlah Murid SMA (Swasta)  \
# 0                            4404                             570
# 1                            4365                             675
# 2                            4269                             639
# 3                            4289                             652
# 4                            4077                             642
#
#    sma__Jumlah Murid SMA (Negeri+Swasta)  smk__Jumlah Sekolah SMK (Negeri)  \
# 0                                   4974                                10
# 1                                   5040                                10
# 2                                   4908                                10
# 3                                   4941                                10
# 4                                   4719                                10
#
#    smk__Jumlah Sekolah SMK (Swasta)  smk__Jumlah Sekolah SMK (Negeri+Swasta)  \
# 0                                 1                                       11
# 1                                 1                                       11
# 2                                 1                                       11
# 3                                 1                                       11
# 4                                 1                                       11
#
#    smk__Jumlah Guru SMK (Negeri)  smk__Jumlah Guru SMK (Swasta)  \
# 0                            297                             16
# 1                            296                             14
# 2                            300                             15
# 3                            305                             16
# 4                            312                             20
#
#    smk__Jumlah Guru SMK (Negeri+Swasta)  smk__Jumlah Murid SMK (Negeri)  \
# 0                                   313                            2469
# 1                                   310                            2578
# 2                                   316                            2606
# 3                                   321                            2633
# 4                                   332                            2619
#
#    smk__Jumlah Murid SMK (Swasta)  smk__Jumlah Murid SMK (Negeri+Swasta)
# 0                              42                                   2511
# 1                              26                                   2604
# 2                              30                                   2635
# 3                              33                                   2666
# 4                              66                                   2685

# %% [markdown]
# ## 3. Agregasi ke Level Kabupaten/Kota
#
# Data diagregasi dengan rata-rata tahun 2016-2025 per kabupaten/kota.

# %%
numeric_cols = df.columns.drop([
    "kabupaten_kota",
    "tahun"
])

agg = (
    df
    .groupby("kabupaten_kota")[numeric_cols]
    .mean()
    .reset_index()
)

print("Ukuran data setelah agregasi :",agg.shape)
display(agg.head())
# Out:
# Ukuran data setelah agregasi : (23, 40)
#               kabupaten_kota  hls__nilai  rls__nilai  amh__nilai  \
# 0       Kabupaten Aceh Barat      14.664       9.466      98.080
# 1  Kabupaten Aceh Barat Daya      13.616       8.487      96.099
# 2       Kabupaten Aceh Besar      14.688      10.240      98.490
# 3        Kabupaten Aceh Jaya      13.994      89.089      96.632
# 4     Kabupaten Aceh Selatan      14.372       8.671      96.996
#
#    sd__Jumlah Sekolah SD (Negeri)  sd__Jumlah Sekolah SD (Swasta)  \
# 0                           149.9                             4.4
# 1                           107.0                             3.0
# 2                           201.4                            11.0
# 3                            98.0                             0.0
# 4                           201.5                             3.2
#
#    sd__Jumlah Sekolah SD (Negeri+Swasta)  sd__Jumlah Guru SD (Negeri)  \
# 0                                  154.4                       2190.9
# 1                                  110.0                       1502.1
# 2                                  212.5                       2496.8
# 3                                   98.0                       1051.8
# 4                                  204.9                       2568.2
#
#    sd__Jumlah Guru SD (Swasta)  sd__Jumlah Guru SD (Negeri+Swasta)  \
# 0                         58.7                              2263.8
# 1                         36.5                              1533.4
# 2                        213.3                              2710.3
# 3                          0.0                              1070.8
# 4                         30.8                              2586.0
#
#    sd__Jumlah Murid SD (Negeri)  sd__Jumlah Murid SD (Swasta)  \
# 0                       15429.3                         582.8
# 1                       11797.9                         534.4
# 2                       27836.0                        2984.1
# 3                        9124.1                           0.0
# 4                       19623.0                         425.9
#
#    sd__Jumlah Murid SD (Negeri+Swasta)  smp__Jumlah Sekolah SMP (Negeri)  \
# 0                              16017.5                              44.7
# 1                              12335.5                              24.0
# 2                              30950.3                              51.7
# 3                               9184.1                              30.8
# 4                              20074.0                              52.1
#
#    smp__Jumlah Sekolah SMP (Swasta)  smp__Jumlah Sekolah SMP (Negeri+Swasta)  \
# 0                              13.0                                     57.7
# 1                               6.2                                     30.2
# 2                              27.8                                     79.5
# 3                               5.1                                     35.9
# 4                               7.7                                     59.8
#
#    smp__Jumlah Guru SMP (Negeri)  smp__Jumlah Guru SMP (Swasta)  \
# 0                          824.1                          143.5
# 1                          562.3                           74.6
# 2                         1071.0                          308.9
# 3                          437.2                           65.7
# 4                          940.9                           82.4
#
#    smp__Jumlah Guru SMP (Negeri+Swasta)  smp__Jumlah Murid SMP (Negeri)  \
# 0                                 967.6                          5176.6
# 1                                 636.9                          4848.0
# 2                                1379.9                          9573.2
# 3                                 502.9                          2840.6
# 4                                1023.3                          8098.2
#
#    smp__Jumlah Murid SMP (Swasta)  smp__Jumlah Murid SMP (Negeri+Swasta)  \
# 0                          1158.6                                 6335.2
# 1                           624.3                                 5472.3
# 2                          4107.0                                13680.2
# 3                           642.7                                 3483.3
# 4                           685.4                                 8783.6
#
#    sma__Jumlah Sekolah SMA (Negeri)  sma__Jumlah Sekolah SMA (Swasta)  \
# 0                              17.0                               4.4
# 1                              13.0                               2.0
# 2                              28.2                              17.0
# 3                              11.0                               3.0
# 4                              28.0                               5.4
#
#    sma__Jumlah Sekolah SMA (Negeri+Swasta)  sma__Jumlah Guru SMA (Negeri)  \
# 0                                     21.4                          430.6
# 1                                     15.0                          419.2
# 2                                     45.2                          822.2
# 3                                     14.0                          216.6
# 4                                     33.4                          769.4
#
#    sma__Jumlah Guru SMA (Swasta)  sma__Jumlah Guru SMA (Negeri+Swasta)  \
# 0                           65.6                                 496.2
# 1                           31.4                                 450.6
# 2                          200.5                                1022.7
# 3                           39.7                                 256.3
# 4                           71.4                                 840.8
#
#    sma__Jumlah Murid SMA (Negeri)  sma__Jumlah Murid SMA (Swasta)  \
# 0                          4177.3                           634.3
# 1                          4447.4                           298.2
# 2                          6390.1                          2036.8
# 3                          1954.1                           437.9
# 4                          6486.9                           465.3
#
#    sma__Jumlah Murid SMA (Negeri+Swasta)  smk__Jumlah Sekolah SMK (Negeri)  \
# 0                                 4811.6                              10.4
# 1                                 4745.6                               5.0
# 2                                 8426.9                               7.9
# 3                                 2392.0                               6.0
# 4                                 6952.2                              10.0
#
#    smk__Jumlah Sekolah SMK (Swasta)  smk__Jumlah Sekolah SMK (Negeri+Swasta)  \
# 0                               0.6                                     11.0
# 1                               0.0                                      5.0
# 2                               2.9                                     10.8
# 3                               1.0                                      7.0
# 4                               1.3                                     11.3
#
#    smk__Jumlah Guru SMK (Negeri)  smk__Jumlah Guru SMK (Swasta)  \
# 0                          328.3                            9.6
# 1                          154.6                            0.0
# 2                          379.3                           32.1
# 3                          114.6                           14.4
# 4                          270.8                           13.2
#
#    smk__Jumlah Guru SMK (Negeri+Swasta)  smk__Jumlah Murid SMK (Negeri)  \
# 0                                 338.0                          2680.8
# 1                                 154.6                          1105.8
# 2                                 411.4                          2852.6
# 3                                 129.0                           717.8
# 4                                 284.1                          1449.4
#
#    smk__Jumlah Murid SMK (Swasta)  smk__Jumlah Murid SMK (Negeri+Swasta)
# 0                            25.2                                 2705.9
# 1                             0.0                                 1105.8
# 2                           405.6                                 3258.2
# 3                           138.7                                  856.5
# 4                            80.2                                 1529.6

# %% [markdown]
# ## 4. Feature Engineering
#
# Fitur berupa angka mentah (bukan rasio) jumlah sekolah, guru, dan murid per jenjang (kolom Total Negeri+Swasta), karena tujuannya mengukur skala/ukuran.

# %% [markdown]
# ## 4.1. Integrasi Fitur Spasial untuk Spatial K-Means
# **Penjelasan Metodologi Analisis Spasial:**
# Untuk menjawab kebutuhan **Analisis Spasial (Spatial Analysis)**, algoritma K-Means kini menggunakan matriks fitur terintegrasi yang mencakup **fitur geografis/spasial** (`latitude` dan `longitude`) dari koordinat sentroid masing-masing Kabupaten/Kota di Provinsi Aceh, disamping indikator atribut pendidikan.
#
# Dengan pendekatan **Spatial-Attribute K-Means** ini, pengelompokan yang dihasilkan oleh K-Means memperhitungkan dua dimensi secara simultan:
# 1. **Kedekatan Lokasi Geografis (Spatial Proximity)**: Memastikan wilayah yang secara geografis berdekatan/bertetangga dipertimbangkan dalam pembentukan klaster.
# 2. **Kemiripan Indikator Pendidikan (Attribute Similarity)**: Memastikan karakteristik atribut pendidikan (seperti HLS, RLS, AMH, dan rasio-rasio pendidikan) tetap dioptimalkan.

# %%
levels = [
    "sd",
    "smp",
    "sma",
    "smk"
]
feat = pd.DataFrame()

feat["kabupaten_kota"] = agg["kabupaten_kota"]

# Fitur Koordinat Spasial (Latitude & Longitude)
koordinat_aceh = {
    'Kabupaten Aceh Barat': (4.45, 96.16),
    'Kabupaten Aceh Barat Daya': (3.83, 96.89),
    'Kabupaten Aceh Besar': (5.38, 95.52),
    'Kabupaten Aceh Jaya': (4.72, 95.64),
    'Kabupaten Aceh Selatan': (3.31, 97.18),
    'Kabupaten Aceh Singkil': (2.42, 97.93),
    'Kabupaten Aceh Tengah': (4.54, 96.91),
    'Kabupaten Aceh Tenggara': (3.37, 97.80),
    'Kabupaten Aceh Timur': (4.63, 97.63),
    'Kabupaten Aceh Utara': (4.97, 97.14),
    'Kabupaten Bener Meriah': (4.73, 96.86),
    'Kabupaten Bireuen': (5.14, 96.62),
    'Kabupaten Gayo Lues': (3.96, 97.33),
    'Kabupaten Nagan Raya': (4.16, 96.43),
    'Kabupaten Pidie': (5.16, 95.96),
    'Kabupaten Pidie Jaya': (5.23, 96.22),
    'Kabupaten Simeulue': (2.61, 96.08),
    'Kota Banda Aceh': (5.55, 95.32),
    'Kota Langsa': (4.47, 97.96),
    'Kota Lhokseumawe': (5.18, 97.14),
    'Kota Sabang': (5.88, 95.32),
    'Kota Subulussalam': (2.64, 97.93),
    'Kabupaten Aceh Tamiang': (4.25, 98.02)
}
feat['latitude'] = feat['kabupaten_kota'].map(lambda x: koordinat_aceh.get(x, (0,0))[0])
feat['longitude'] = feat['kabupaten_kota'].map(lambda x: koordinat_aceh.get(x, (0,0))[1])
for lv in levels:
    feat[f"{lv}_sekolah"] = (
        agg[f"{lv}__Jumlah Sekolah {lv.upper()} (Negeri+Swasta)"]
    )
    feat[f"{lv}_guru"] = (
        agg[f"{lv}__Jumlah Guru {lv.upper()} (Negeri+Swasta)"]
    )
    feat[f"{lv}_murid"] = (
        agg[f"{lv}__Jumlah Murid {lv.upper()} (Negeri+Swasta)"]
    )
feat = feat.fillna(0)

print("Ukuran fitur :",feat.shape)
display(feat.head())
# Out:
# Ukuran fitur : (23, 15)
#               kabupaten_kota  latitude  longitude  sd_sekolah  sd_guru  \
# 0       Kabupaten Aceh Barat      4.45      96.16       154.4   2263.8
# 1  Kabupaten Aceh Barat Daya      3.83      96.89       110.0   1533.4
# 2       Kabupaten Aceh Besar      5.38      95.52       212.5   2710.3
# 3        Kabupaten Aceh Jaya      4.72      95.64        98.0   1070.8
# 4     Kabupaten Aceh Selatan      3.31      97.18       204.9   2586.0
#
#    sd_murid  smp_sekolah  smp_guru  smp_murid  sma_sekolah  sma_guru  \
# 0   16017.5         57.7     967.6     6335.2         21.4     496.2
# 1   12335.5         30.2     636.9     5472.3         15.0     450.6
# 2   30950.3         79.5    1379.9    13680.2         45.2    1022.7
# 3    9184.1         35.9     502.9     3483.3         14.0     256.3
# 4   20074.0         59.8    1023.3     8783.6         33.4     840.8
#
#    sma_murid  smk_sekolah  smk_guru  smk_murid
# 0     4811.6         11.0     338.0     2705.9
# 1     4745.6          5.0     154.6     1105.8
# 2     8426.9         10.8     411.4     3258.2
# 3     2392.0          7.0     129.0      856.5
# 4     6952.2         11.3     284.1     1529.6

# %% [markdown]
# ## 5. Exploratory Data Analysis — Korelasi Antar Fitur

# %%
plt.figure(figsize=(10, 8))
corr = feat.drop(columns=['kabupaten_kota']).corr()
sns.heatmap(corr, cmap='RdBu_r', center=0, annot=True, fmt='.2f', linewidths=0.3, annot_kws={'size':7})
plt.title('Korelasi Antar Fitur Infrastruktur Pendidikan')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Standarisasi Fitur

# %%
X = feat.drop(columns=["kabupaten_kota"])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Ukuran data setelah standarisasi :", X_scaled.shape)
print("Rata-rata :", np.round(X_scaled.mean(axis=0),3)[:5])
print("Standar Deviasi :", np.round(X_scaled.std(axis=0),3)[:5])
# Out:
# Ukuran data setelah standarisasi : (23, 14)
# Rata-rata : [ 0.  0.  0. -0.  0.]
# Standar Deviasi : [1. 1. 1. 1. 1.]

# %% [markdown]
# ## 7. Menentukan Jumlah Cluster Optimal (Elbow Method & Silhouette Score)

# %%
K_range = range(2, 9)
inertias, sil_scores = [], []
for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(X_scaled)
    inertias.append(km.inertia_)
    sil_scores.append(silhouette_score(X_scaled, labels))

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
axes[0].plot(list(K_range), inertias, marker='o', color='#2c7fb8')
axes[0].set_xlabel('Jumlah Cluster (k)'); axes[0].set_ylabel('Inertia'); axes[0].set_title('Elbow Method')
axes[1].plot(list(K_range), sil_scores, marker='o', color='#e6550d')
axes[1].set_xlabel('Jumlah Cluster (k)'); axes[1].set_ylabel('Silhouette Score'); axes[1].set_title('Silhouette Score')
plt.tight_layout()
plt.show()

for k, i, s in zip(K_range, inertias, sil_scores):
    print(f"k={k}: inertia={i:.2f}, silhouette={s:.4f}")
# Out:
# k=2: inertia=159.72, silhouette=0.4593
# k=3: inertia=118.91, silhouette=0.2660
# k=4: inertia=90.17, silhouette=0.2686
# k=5: inertia=74.70, silhouette=0.2680
# k=6: inertia=61.91, silhouette=0.2613
# k=7: inertia=49.59, silhouette=0.2438
# k=8: inertia=39.52, silhouette=0.2328

# %% [markdown]
# ## 8. Fit K-Means Final

# %%
best_k = K_range[np.argmax(sil_scores)]

best_score = max(sil_scores)

kmeans_final = KMeans(n_clusters=best_k, random_state=42, n_init=10)
feat["cluster"] = kmeans_final.fit_predict(X_scaled)

print("Jumlah Cluster Terbaik :",best_k)

print("Silhouette Score :",round(best_score,4))
# Out:
# Jumlah Cluster Terbaik : 2
# Silhouette Score : 0.4593

# %% [markdown]
# ## 9. Visualisasi Cluster dengan PCA (2D)

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)
print("Variance explained:", round(pca.explained_variance_ratio_.sum()*100, 1), "%")

plt.figure(figsize=(9, 7))
palette = ['#2c7fb8', '#e6550d', '#31a354', '#756bb1', '#de2d26'][:3]
for c in sorted(feat['cluster'].unique()):
    mask = feat['cluster'] == c
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], s=110, color=palette[c], label=f'Cluster {c}', edgecolor='white')
for i, row in feat.iterrows():
    plt.annotate(row['kabupaten_kota'].replace('Kabupaten ', '').replace('Kota ', ''),
                 (X_pca[i, 0], X_pca[i, 1]), fontsize=8, xytext=(4, 4), textcoords='offset points')
plt.xlabel('PCA Komponen 1'); plt.ylabel('PCA Komponen 2')
plt.title('Skala Infrastruktur — Visualisasi Cluster (PCA 2D)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Variance explained: 85.9 %

# %% [markdown]
# ## 10. Profil Rata-Rata Tiap Cluster

# %%
profile = feat.drop(columns=['kabupaten_kota']).groupby('cluster').mean().round(1)
profile
# Out:
#          latitude  longitude  sd_sekolah  sd_guru  sd_murid  smp_sekolah  \
# cluster
# 0             4.2       96.8       118.2   1536.2   15986.8         41.6
# 1             5.1       96.6       275.9   4055.3   40917.4         92.9
#
#          smp_guru  smp_murid  sma_sekolah  sma_guru  sma_murid  smk_sekolah  \
# cluster
# 0           724.9     6408.4         18.6     468.4     4640.9          7.7
# 1          2036.6    17207.6         39.2    1148.7    10439.9         15.6
#
#          smk_guru  smk_murid
# cluster
# 0           231.5     1941.6
# 1           496.5     3980.5

# %%
hasil_cluster = feat.copy()

hasil_cluster.to_csv(
    "hasil_cluster_tema2.csv",
    index=False
)

print("Hasil clustering berhasil disimpan.")
# Out:
# Hasil clustering berhasil disimpan.

# %% [markdown]
# ## 11. Kesimpulan Analisis
#
# Berdasarkan hasil K-Means, kabupaten/kota di Aceh terbagi menjadi dua kelompok berdasarkan skala infrastruktur pendidikan.
#
# - **Cluster 0** terdiri atas kabupaten/kota dengan jumlah sekolah, guru, dan murid yang relatif lebih sedikit pada seluruh jenjang pendidikan. Cluster ini didominasi oleh wilayah dengan ukuran populasi yang lebih kecil sehingga kebutuhan infrastruktur pendidikan juga lebih rendah.
#
# - **Cluster 1** terdiri atas kabupaten yang memiliki jumlah sekolah, guru, dan murid lebih besar dibandingkan Cluster 0. Wilayah pada cluster ini umumnya merupakan kabupaten dengan populasi yang lebih besar sehingga membutuhkan kapasitas layanan pendidikan yang lebih tinggi.
#
# **Interpretasi utama**
#
# Perbedaan kedua cluster lebih menggambarkan **skala infrastruktur pendidikan**, bukan kualitas pendidikan. Oleh karena itu, hasil clustering ini dapat menjadi dasar dalam perencanaan kebutuhan pembangunan sekolah, distribusi guru, dan penyediaan layanan pendidikan sesuai ukuran wilayah.
