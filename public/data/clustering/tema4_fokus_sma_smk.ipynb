# %% [markdown]
# # Tema 4: Clustering Kabupaten/Kota Aceh Berdasarkan Fokus Jenjang (SMA vs SMK)
#
# **Skenario 1 — Clustering** | Dataset: `data_bersih.csv`
#
# **Pertanyaan:** Kabupaten mana yang lebih condong ke pendidikan vokasi (SMK) dibanding akademik (SMA)?

# %% [markdown]
# ## 1. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

sns.set_style("whitegrid")

pd.set_option("display.max_columns",None)

print("Library berhasil diimport.")
# Out:
# Library berhasil diimport.

# %% [markdown]
# ## 2. Load Dataset

# %%
df = pd.read_csv("data_bersih.csv")

print("Ukuran data :",df.shape)

print("Jumlah kabupaten :",df["kabupaten_kota"].nunique())

print("Rentang tahun :",
      df["tahun"].min(),
      "-",
      df["tahun"].max())

print("Missing :",df.isna().sum().sum())

print("Duplikat :",df.duplicated().sum())

display(df.head())
# Out:
# Ukuran data : (230, 41)
# Jumlah kabupaten : 23
# Rentang tahun : 2016 - 2025
# Missing : 0
# Duplikat : 0
#          kabupaten_kota  tahun  hls__nilai  rls__nilai  amh__nilai  \
# 0  Kabupaten Aceh Barat   2016       14.56        8.70       97.84
# 1  Kabupaten Aceh Barat   2017       14.57        9.04       97.84
# 2  Kabupaten Aceh Barat   2018       14.58        9.08       97.84
# 3  Kabupaten Aceh Barat   2019       14.59        9.09       97.84
# 4  Kabupaten Aceh Barat   2020       14.60        9.37       97.84
#
#    sd__Jumlah Sekolah SD (Negeri)  sd__Jumlah Sekolah SD (Swasta)  \
# 0                             148                               4
# 1                             150                               3
# 2                             150                               3
# 3                             150                               3
# 4                             150                               3
#
#    sd__Jumlah Sekolah SD (Negeri+Swasta)  sd__Jumlah Guru SD (Negeri)  \
# 0                                    153                         2125
# 1                                    153                         2050
# 2                                    153                         2127
# 3                                    153                         2276
# 4                                    153                         2367
#
#    sd__Jumlah Guru SD (Swasta)  sd__Jumlah Guru SD (Negeri+Swasta)  \
# 0                           48                                2315
# 1                           41                                2091
# 2                           36                                2163
# 3                           39                                2315
# 4                           38                                2405
#
#    sd__Jumlah Murid SD (Negeri)  sd__Jumlah Murid SD (Swasta)  \
# 0                         15757                           422
# 1                         16169                           414
# 2                         15694                           467
# 3                         15718                           515
# 4                         15377                           542
#
#    sd__Jumlah Murid SD (Negeri+Swasta)  smp__Jumlah Sekolah SMP (Negeri)  \
# 0                                16233                                39
# 1                                16583                                45
# 2                                16161                                45
# 3                                16233                                45
# 4                                15919                                45
#
#    smp__Jumlah Sekolah SMP (Swasta)  smp__Jumlah Sekolah SMP (Negeri+Swasta)  \
# 0                                10                                       49
# 1                                 8                                       53
# 2                                 9                                       54
# 3                                11                                       56
# 4                                13                                       58
#
#    smp__Jumlah Guru SMP (Negeri)  smp__Jumlah Guru SMP (Swasta)  \
# 0                            658                             93
# 1                            727                             88
# 2                            757                            106
# 3                            774                            130
# 4                            850                            173
#
#    smp__Jumlah Guru SMP (Negeri+Swasta)  smp__Jumlah Murid SMP (Negeri)  \
# 0                                   751                            5270
# 1                                   815                            5427
# 2                                   863                            5391
# 3                                   904                            5649
# 4                                  1023                            5544
#
#    smp__Jumlah Murid SMP (Swasta)  smp__Jumlah Murid SMP (Negeri+Swasta)  \
# 0                             698                                   5968
# 1                             631                                   6058
# 2                             783                                   6174
# 3                            1006                                   6655
# 4                            1176                                   6720
#
#    sma__Jumlah Sekolah SMA (Negeri)  sma__Jumlah Sekolah SMA (Swasta)  \
# 0                                17                                 4
# 1                                17                                 4
# 2                                17                                 4
# 3                                17                                 4
# 4                                17                                 4
#
#    sma__Jumlah Sekolah SMA (Negeri+Swasta)  sma__Jumlah Guru SMA (Negeri)  \
# 0                                       21                            434
# 1                                       21                            431
# 2                                       21                            421
# 3                                       21                            423
# 4                                       21                            433
#
#    sma__Jumlah Guru SMA (Swasta)  sma__Jumlah Guru SMA (Negeri+Swasta)  \
# 0                             58                                   492
# 1                             61                                   492
# 2                             65                                   486
# 3                             67                                   490
# 4                             68                                   501
#
#    sma__Jumlah Murid SMA (Negeri)  sma__Jumlah Murid SMA (Swasta)  \
# 0                            4404                             570
# 1                            4365                             675
# 2                            4269                             639
# 3                            4289                             652
# 4                            4077                             642
#
#    sma__Jumlah Murid SMA (Negeri+Swasta)  smk__Jumlah Sekolah SMK (Negeri)  \
# 0                                   4974                                10
# 1                                   5040                                10
# 2                                   4908                                10
# 3                                   4941                                10
# 4                                   4719                                10
#
#    smk__Jumlah Sekolah SMK (Swasta)  smk__Jumlah Sekolah SMK (Negeri+Swasta)  \
# 0                                 1                                       11
# 1                                 1                                       11
# 2                                 1                                       11
# 3                                 1                                       11
# 4                                 1                                       11
#
#    smk__Jumlah Guru SMK (Negeri)  smk__Jumlah Guru SMK (Swasta)  \
# 0                            297                             16
# 1                            296                             14
# 2                            300                             15
# 3                            305                             16
# 4                            312                             20
#
#    smk__Jumlah Guru SMK (Negeri+Swasta)  smk__Jumlah Murid SMK (Negeri)  \
# 0                                   313                            2469
# 1                                   310                            2578
# 2                                   316                            2606
# 3                                   321                            2633
# 4                                   332                            2619
#
#    smk__Jumlah Murid SMK (Swasta)  smk__Jumlah Murid SMK (Negeri+Swasta)
# 0                              42                                   2511
# 1                              26                                   2604
# 2                              30                                   2635
# 3                              33                                   2666
# 4                              66                                   2685

# %% [markdown]
# ## 3. Agregasi ke Level Kabupaten/Kota

# %%
numeric_cols = df.columns.drop(['kabupaten_kota', 'tahun'])
agg = df.groupby('kabupaten_kota')[numeric_cols].mean().reset_index()
levels = ['sd', 'smp', 'sma', 'smk']
print("Ukuran data setelah agregasi:", agg.shape)
agg.head()
# Out:
# Ukuran data setelah agregasi: (23, 40)
#               kabupaten_kota  hls__nilai  rls__nilai  amh__nilai  \
# 0       Kabupaten Aceh Barat      14.664       9.466      98.080
# 1  Kabupaten Aceh Barat Daya      13.616       8.487      96.099
# 2       Kabupaten Aceh Besar      14.688      10.240      98.490
# 3        Kabupaten Aceh Jaya      13.994      89.089      96.632
# 4     Kabupaten Aceh Selatan      14.372       8.671      96.996
#
#    sd__Jumlah Sekolah SD (Negeri)  sd__Jumlah Sekolah SD (Swasta)  \
# 0                           149.9                             4.4
# 1                           107.0                             3.0
# 2                           201.4                            11.0
# 3                            98.0                             0.0
# 4                           201.5                             3.2
#
#    sd__Jumlah Sekolah SD (Negeri+Swasta)  sd__Jumlah Guru SD (Negeri)  \
# 0                                  154.4                       2190.9
# 1                                  110.0                       1502.1
# 2                                  212.5                       2496.8
# 3                                   98.0                       1051.8
# 4                                  204.9                       2568.2
#
#    sd__Jumlah Guru SD (Swasta)  sd__Jumlah Guru SD (Negeri+Swasta)  \
# 0                         58.7                              2263.8
# 1                         36.5                              1533.4
# 2                        213.3                              2710.3
# 3                          0.0                              1070.8
# 4                         30.8                              2586.0
#
#    sd__Jumlah Murid SD (Negeri)  sd__Jumlah Murid SD (Swasta)  \
# 0                       15429.3                         582.8
# 1                       11797.9                         534.4
# 2                       27836.0                        2984.1
# 3                        9124.1                           0.0
# 4                       19623.0                         425.9
#
#    sd__Jumlah Murid SD (Negeri+Swasta)  smp__Jumlah Sekolah SMP (Negeri)  \
# 0                              16017.5                              44.7
# 1                              12335.5                              24.0
# 2                              30950.3                              51.7
# 3                               9184.1                              30.8
# 4                              20074.0                              52.1
#
#    smp__Jumlah Sekolah SMP (Swasta)  smp__Jumlah Sekolah SMP (Negeri+Swasta)  \
# 0                              13.0                                     57.7
# 1                               6.2                                     30.2
# 2                              27.8                                     79.5
# 3                               5.1                                     35.9
# 4                               7.7                                     59.8
#
#    smp__Jumlah Guru SMP (Negeri)  smp__Jumlah Guru SMP (Swasta)  \
# 0                          824.1                          143.5
# 1                          562.3                           74.6
# 2                         1071.0                          308.9
# 3                          437.2                           65.7
# 4                          940.9                           82.4
#
#    smp__Jumlah Guru SMP (Negeri+Swasta)  smp__Jumlah Murid SMP (Negeri)  \
# 0                                 967.6                          5176.6
# 1                                 636.9                          4848.0
# 2                                1379.9                          9573.2
# 3                                 502.9                          2840.6
# 4                                1023.3                          8098.2
#
#    smp__Jumlah Murid SMP (Swasta)  smp__Jumlah Murid SMP (Negeri+Swasta)  \
# 0                          1158.6                                 6335.2
# 1                           624.3                                 5472.3
# 2                          4107.0                                13680.2
# 3                           642.7                                 3483.3
# 4                           685.4                                 8783.6
#
#    sma__Jumlah Sekolah SMA (Negeri)  sma__Jumlah Sekolah SMA (Swasta)  \
# 0                              17.0                               4.4
# 1                              13.0                               2.0
# 2                              28.2                              17.0
# 3                              11.0                               3.0
# 4                              28.0                               5.4
#
#    sma__Jumlah Sekolah SMA (Negeri+Swasta)  sma__Jumlah Guru SMA (Negeri)  \
# 0                                     21.4                          430.6
# 1                                     15.0                          419.2
# 2                                     45.2                          822.2
# 3                                     14.0                          216.6
# 4                                     33.4                          769.4
#
#    sma__Jumlah Guru SMA (Swasta)  sma__Jumlah Guru SMA (Negeri+Swasta)  \
# 0                           65.6                                 496.2
# 1                           31.4                                 450.6
# 2                          200.5                                1022.7
# 3                           39.7                                 256.3
# 4                           71.4                                 840.8
#
#    sma__Jumlah Murid SMA (Negeri)  sma__Jumlah Murid SMA (Swasta)  \
# 0                          4177.3                           634.3
# 1                          4447.4                           298.2
# 2                          6390.1                          2036.8
# 3                          1954.1                           437.9
# 4                          6486.9                           465.3
#
#    sma__Jumlah Murid SMA (Negeri+Swasta)  smk__Jumlah Sekolah SMK (Negeri)  \
# 0                                 4811.6                              10.4
# 1                                 4745.6                               5.0
# 2                                 8426.9                               7.9
# 3                                 2392.0                               6.0
# 4                                 6952.2                              10.0
#
#    smk__Jumlah Sekolah SMK (Swasta)  smk__Jumlah Sekolah SMK (Negeri+Swasta)  \
# 0                               0.6                                     11.0
# 1                               0.0                                      5.0
# 2                               2.9                                     10.8
# 3                               1.0                                      7.0
# 4                               1.3                                     11.3
#
#    smk__Jumlah Guru SMK (Negeri)  smk__Jumlah Guru SMK (Swasta)  \
# 0                          328.3                            9.6
# 1                          154.6                            0.0
# 2                          379.3                           32.1
# 3                          114.6                           14.4
# 4                          270.8                           13.2
#
#    smk__Jumlah Guru SMK (Negeri+Swasta)  smk__Jumlah Murid SMK (Negeri)  \
# 0                                 338.0                          2680.8
# 1                                 154.6                          1105.8
# 2                                 411.4                          2852.6
# 3                                 129.0                           717.8
# 4                                 284.1                          1449.4
#
#    smk__Jumlah Murid SMK (Swasta)  smk__Jumlah Murid SMK (Negeri+Swasta)
# 0                            25.2                                 2705.9
# 1                             0.0                                 1105.8
# 2                           405.6                                 3258.2
# 3                           138.7                                  856.5
# 4                            80.2                                 1529.6

# %% [markdown]
# ## 4. Feature Engineering
#
# Fitur berupa proporsi murid, sekolah, dan guru SMA dibanding total SMA+SMK.

# %% [markdown]
# ## 4.1. Integrasi Fitur Spasial untuk Spatial K-Means
# **Penjelasan Metodologi Analisis Spasial:**
# Untuk menjawab kebutuhan **Analisis Spasial (Spatial Analysis)**, algoritma K-Means kini menggunakan matriks fitur terintegrasi yang mencakup **fitur geografis/spasial** (`latitude` dan `longitude`) dari koordinat sentroid masing-masing Kabupaten/Kota di Provinsi Aceh, disamping indikator atribut pendidikan.
#
# Dengan pendekatan **Spatial-Attribute K-Means** ini, pengelompokan yang dihasilkan oleh K-Means memperhitungkan dua dimensi secara simultan:
# 1. **Kedekatan Lokasi Geografis (Spatial Proximity)**: Memastikan wilayah yang secara geografis berdekatan/bertetangga dipertimbangkan dalam pembentukan klaster.
# 2. **Kemiripan Indikator Pendidikan (Attribute Similarity)**: Memastikan karakteristik atribut pendidikan (seperti HLS, RLS, AMH, dan rasio-rasio pendidikan) tetap dioptimalkan.

# %%
feat = pd.DataFrame()
feat["kabupaten_kota"] = agg["kabupaten_kota"]

# Fitur Koordinat Spasial (Latitude & Longitude)
koordinat_aceh = {
    'Kabupaten Aceh Barat': (4.45, 96.16),
    'Kabupaten Aceh Barat Daya': (3.83, 96.89),
    'Kabupaten Aceh Besar': (5.38, 95.52),
    'Kabupaten Aceh Jaya': (4.72, 95.64),
    'Kabupaten Aceh Selatan': (3.31, 97.18),
    'Kabupaten Aceh Singkil': (2.42, 97.93),
    'Kabupaten Aceh Tengah': (4.54, 96.91),
    'Kabupaten Aceh Tenggara': (3.37, 97.80),
    'Kabupaten Aceh Timur': (4.63, 97.63),
    'Kabupaten Aceh Utara': (4.97, 97.14),
    'Kabupaten Bener Meriah': (4.73, 96.86),
    'Kabupaten Bireuen': (5.14, 96.62),
    'Kabupaten Gayo Lues': (3.96, 97.33),
    'Kabupaten Nagan Raya': (4.16, 96.43),
    'Kabupaten Pidie': (5.16, 95.96),
    'Kabupaten Pidie Jaya': (5.23, 96.22),
    'Kabupaten Simeulue': (2.61, 96.08),
    'Kota Banda Aceh': (5.55, 95.32),
    'Kota Langsa': (4.47, 97.96),
    'Kota Lhokseumawe': (5.18, 97.14),
    'Kota Sabang': (5.88, 95.32),
    'Kota Subulussalam': (2.64, 97.93),
    'Kabupaten Aceh Tamiang': (4.25, 98.02)
}
feat['latitude'] = feat['kabupaten_kota'].map(lambda x: koordinat_aceh.get(x, (0,0))[0])
feat['longitude'] = feat['kabupaten_kota'].map(lambda x: koordinat_aceh.get(x, (0,0))[1])

# ======================
# Sekolah
# ======================
total_sekolah = (
    agg["sma__Jumlah Sekolah SMA (Negeri+Swasta)"] +
    agg["smk__Jumlah Sekolah SMK (Negeri+Swasta)"]
)

feat["prop_sekolah_sma"] = (
    agg["sma__Jumlah Sekolah SMA (Negeri+Swasta)"] / total_sekolah
)

feat["prop_sekolah_smk"] = (
    agg["smk__Jumlah Sekolah SMK (Negeri+Swasta)"] / total_sekolah
)

# ======================
# Guru
# ======================
total_guru = (
    agg["sma__Jumlah Guru SMA (Negeri+Swasta)"] +
    agg["smk__Jumlah Guru SMK (Negeri+Swasta)"]
)

feat["prop_guru_sma"] = (
    agg["sma__Jumlah Guru SMA (Negeri+Swasta)"] / total_guru
)

feat["prop_guru_smk"] = (
    agg["smk__Jumlah Guru SMK (Negeri+Swasta)"] / total_guru
)

# ======================
# Murid
# ======================
total_murid = (
    agg["sma__Jumlah Murid SMA (Negeri+Swasta)"] +
    agg["smk__Jumlah Murid SMK (Negeri+Swasta)"]
)

feat["prop_murid_sma"] = (
    agg["sma__Jumlah Murid SMA (Negeri+Swasta)"] / total_murid
)

feat["prop_murid_smk"] = (
    agg["smk__Jumlah Murid SMK (Negeri+Swasta)"] / total_murid
)

# Membersihkan nilai
feat.replace([np.inf, -np.inf], np.nan, inplace=True)
feat.fillna(0, inplace=True)

print("Ukuran fitur:", feat.shape)
display(feat.head())
# Out:
# Ukuran fitur: (23, 9)
#               kabupaten_kota  latitude  longitude  prop_sekolah_sma  \
# 0       Kabupaten Aceh Barat      4.45      96.16          0.660494
# 1  Kabupaten Aceh Barat Daya      3.83      96.89          0.750000
# 2       Kabupaten Aceh Besar      5.38      95.52          0.807143
# 3        Kabupaten Aceh Jaya      4.72      95.64          0.666667
# 4     Kabupaten Aceh Selatan      3.31      97.18          0.747204
#
#    prop_sekolah_smk  prop_guru_sma  prop_guru_smk  prop_murid_sma  \
# 0          0.339506       0.594821       0.405179        0.640053
# 1          0.250000       0.744547       0.255453        0.811020
# 2          0.192857       0.713130       0.286870        0.721166
# 3          0.333333       0.665196       0.334804        0.736340
# 4          0.252796       0.747444       0.252556        0.819661
#
#    prop_murid_smk
# 0        0.359947
# 1        0.188980
# 2        0.278834
# 3        0.263660
# 4        0.180339

# %% [markdown]
# ## 5. Exploratory Data Analysis — Korelasi Antar Fitur

# %%
plt.figure(figsize=(6, 5))
corr = feat.drop(columns=['kabupaten_kota']).corr()
sns.heatmap(corr, cmap='RdBu_r', center=0, annot=True, fmt='.2f', linewidths=0.3)
plt.title('Korelasi Antar Fitur Orientasi SMA-SMK')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Standarisasi Fitur

# %%
X = feat.drop(columns=["kabupaten_kota"])
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print("Ukuran data setelah standarisasi :", X_scaled.shape)
print(
    "Rata-rata :",
    np.round(X_scaled.mean(axis=0),3)
)
print(
    "Standar Deviasi :",
    np.round(X_scaled.std(axis=0),3)
)
# Out:
# Ukuran data setelah standarisasi : (23, 8)
# Rata-rata : [ 0.  0. -0. -0. -0.  0.  0.  0.]
# Standar Deviasi : [1. 1. 1. 1. 1. 1. 1. 1.]

# %% [markdown]
# ## 7. Menentukan Jumlah Cluster Optimal (Elbow Method & Silhouette Score)

# %%
K_range = range(2, 7)
inertias, sil_scores = [], []
for k in K_range:
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = km.fit_predict(X_scaled)
    inertias.append(km.inertia_)
    sil_scores.append(silhouette_score(X_scaled, labels))

fig, axes = plt.subplots(1, 2, figsize=(13, 4.5))
axes[0].plot(list(K_range), inertias, marker='o', color='#2c7fb8')
axes[0].set_xlabel('Jumlah Cluster (k)'); axes[0].set_ylabel('Inertia'); axes[0].set_title('Elbow Method')
axes[1].plot(list(K_range), sil_scores, marker='o', color='#e6550d')
axes[1].set_xlabel('Jumlah Cluster (k)'); axes[1].set_ylabel('Silhouette Score'); axes[1].set_title('Silhouette Score')
plt.tight_layout()
plt.show()

for k, i, s in zip(K_range, inertias, sil_scores):
    print(f"k={k}: inertia={i:.2f}, silhouette={s:.4f}")
# Out:
# k=2: inertia=101.18, silhouette=0.5771
# k=3: inertia=69.98, silhouette=0.2890
# k=4: inertia=44.33, silhouette=0.3467
# k=5: inertia=36.46, silhouette=0.2922
# k=6: inertia=29.41, silhouette=0.2935

# %% [markdown]
# ## 8. Fit K-Means Final (k=2)

# %%
best_k = K_range[
    np.argmax(sil_scores)
]

best_score = max(sil_scores)

print(
    "Jumlah Cluster Terbaik :",
    best_k
)

print(
    "Silhouette Score :",
    round(best_score,4)
)
# Out:
# Jumlah Cluster Terbaik : 2
# Silhouette Score : 0.5771

# %%
kmeans = KMeans(
    n_clusters=best_k,
    random_state=42,
    n_init=10
)

feat["cluster"] = kmeans.fit_predict(
    X_scaled
)

print("Clustering selesai.")
# Out:
# Clustering selesai.

# %%
# Jumlah anggota tiap cluster
print("Jumlah anggota tiap cluster:")
print(feat["cluster"].value_counts().sort_index())

# Daftar anggota tiap cluster
for c in sorted(feat["cluster"].unique()):

    anggota = feat.loc[
        feat["cluster"] == c,
        "kabupaten_kota"
    ].tolist()

    print(f"\n{'='*50}")
    print(f"Cluster {c} ({len(anggota)} kabupaten/kota):")
    print(", ".join(anggota))
# Out:
# Jumlah anggota tiap cluster:
# cluster
# 0    21
# 1     2
# Name: count, dtype: int64
#
# ==================================================
# Cluster 0 (21 kabupaten/kota):
# Kabupaten Aceh Barat, Kabupaten Aceh Barat Daya, Kabupaten Aceh Besar, Kabupaten Aceh Jaya, Kabupaten Aceh Selatan, Kabupaten Aceh Singkil, Kabupaten Aceh Tamiang, Kabupaten Aceh Tengah, Kabupaten Aceh Tenggara, Kabupaten Aceh Timur, Kabupaten Aceh Utara, Kabupaten Bener Meriah, Kabupaten Bireuen, Kabupaten Gayo Lues, Kabupaten Nagan Raya, Kabupaten Pidie, Kabupaten Pidie Jaya, Kabupaten Simeulue, Kota Banda Aceh, Kota Sabang, Kota Subulussalam
#
# ==================================================
# Cluster 1 (2 kabupaten/kota):
# Kota Langsa, Kota Lhokseumawe

# %% [markdown]
# ## 9. Visualisasi Cluster dengan PCA (2D)

# %%
pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_scaled)
print("Variance explained:", round(pca.explained_variance_ratio_.sum()*100, 1), "%")

plt.figure(figsize=(9, 7))
palette = ['#2c7fb8', '#e6550d', '#31a354', '#756bb1', '#de2d26'][:3]
for c in sorted(feat['cluster'].unique()):
    mask = feat['cluster'] == c
    plt.scatter(X_pca[mask, 0], X_pca[mask, 1], s=110, color=palette[c], label=f'Cluster {c}', edgecolor='white')
for i, row in feat.iterrows():
    plt.annotate(row['kabupaten_kota'].replace('Kabupaten ', '').replace('Kota ', ''),
                 (X_pca[i, 0], X_pca[i, 1]), fontsize=8, xytext=(4, 4), textcoords='offset points')
plt.xlabel('PCA Komponen 1'); plt.ylabel('PCA Komponen 2')
plt.title('Fokus SMA vs SMK — Visualisasi Cluster (PCA 2D)')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Variance explained: 89.9 %

# %% [markdown]
# ## 10. Profil Rata-Rata Tiap Cluster

# %%
profile = (
    feat
    .drop(columns="kabupaten_kota")
    .groupby("cluster")
    .mean(numeric_only=True)
    .round(3)
)

display(profile)
# Out:
#          latitude  longitude  prop_sekolah_sma  prop_sekolah_smk  \
# cluster
# 0           4.330     96.709             0.729             0.271
# 1           4.825     97.550             0.493             0.507
#
#          prop_guru_sma  prop_guru_smk  prop_murid_sma  prop_murid_smk
# cluster
# 0                0.703          0.297           0.747           0.253
# 1                0.467          0.533           0.494           0.506

# %%
profile.T.plot(
    figsize=(9,5),
    marker="o"
)

plt.title("Profil Orientasi Pendidikan Menengah")
plt.xlabel("Fitur")
plt.ylabel("Rata-rata")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
hasil_cluster = feat.copy()

hasil_cluster.to_csv(
    "hasil_cluster_tema4.csv",
    index=False
)

print("Hasil clustering berhasil disimpan.")
# Out:
# Hasil clustering berhasil disimpan.

# %% [markdown]
# ## 11. Kesimpulan Analisis
#
# Berdasarkan hasil K-Means, kabupaten/kota di Aceh terbagi menjadi dua kelompok berdasarkan proporsi pendidikan SMA dan SMK.
#
# - **Cluster 0** memiliki proporsi sekolah, guru, dan murid SMA yang lebih tinggi dibandingkan SMK sehingga menunjukkan orientasi pendidikan yang lebih dominan pada jalur akademik.
#
# - **Cluster 1** memiliki proporsi sekolah, guru, dan murid SMK yang relatif lebih tinggi sehingga menunjukkan orientasi yang lebih kuat pada pendidikan vokasi.
#
# **Interpretasi utama**
#
# Perbedaan kedua cluster menunjukkan adanya variasi orientasi penyediaan layanan pendidikan menengah antarwilayah. Informasi ini dapat digunakan sebagai dasar dalam penyusunan kebijakan pengembangan pendidikan akademik maupun vokasi sesuai kebutuhan masing-masing daerah.
